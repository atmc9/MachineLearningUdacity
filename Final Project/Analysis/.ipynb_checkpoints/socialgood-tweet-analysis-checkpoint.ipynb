# %% [markdown]
# # 1- Load data and extract new columns

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from datetime import date
from sklearn import preprocessing
from IPython.display import Image
from IPython.core.display import HTML, display
from PIL.Image as pImage

# %%
SGDS = pd.read_csv('socialgood-datascience_tweets.csv', parse_dates=['date'])
SGDS.drop(['geo'], axis = 1, inplace=True)
SGDS.head(1)
# Out:
#                  date  favorites  \
# 0 2018-03-28 17:44:28          6
#
#                                        hashtags                  id mentions  \
# 0  #datascience #socialgood #socialimpact #data  979112007982084097      NaN
#
#                                            permalink  retweets  \
# 0  https://twitter.com/fromJupyter/status/9791120...         1
#
#                                                 text     username
# 0  Data Science Mentors Needed! Join the Data Sci...  fromJupyter

# %%
SGAI = pd.read_csv('socialgood-ai_tweets.csv', parse_dates=['date'])
SGAI.drop(['geo'], axis = 1, inplace=True)
#SGAI.describe()

# %%
SGML = pd.read_csv('socialgood-ML_tweets.csv', parse_dates=['date'])
SGML.drop(['geo'], axis = 1, inplace=True)
#SGML.describe()

# %%
SGDS_SGAI = pd.concat([SGDS,SGAI]).drop_duplicates().reset_index(drop=True)
#SGDS_SGAI.describe()

# %%
all_tweets = pd.concat([SGDS_SGAI,SGML]).drop_duplicates().reset_index(drop=True)

# %%
#missing data
total = all_tweets.isnull().sum().sort_values(ascending=False)
percent = (all_tweets.isnull().sum()/all_tweets.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#            Total   Percent
# mentions     585  0.481878
# username       0  0.000000
# text           0  0.000000
# retweets       0  0.000000
# permalink      0  0.000000
# id             0  0.000000
# hashtags       0  0.000000
# favorites      0  0.000000
# date           0  0.000000

# %%
all_tweets = all_tweets.fillna('')
all_tweets['hashtags_list'] = all_tweets.hashtags.str.lower().apply(lambda x: x.split('#'))
all_tweets['hashtags_list'] = all_tweets[['hashtags_list']].applymap(lambda x: list(filter(None, x)))
all_tweets['mentions_list'] = all_tweets.mentions.str.lower().apply(lambda x: x.split('@'))
all_tweets['mentions_list'] = all_tweets[['mentions_list']].applymap(lambda x: list(filter(None, x)))
 

all_tweets["count_hashtags"] = all_tweets[['hashtags']].applymap(lambda x: str.count(x, '#'))
all_tweets["count_mentions"] = all_tweets[['mentions']].applymap(lambda x: str.count(x, '@'))

# %%
all_tweets.hashtags_list[0]
# Out:
# ['datascience ', 'socialgood ', 'socialimpact ', 'data']

# %%
lbl = preprocessing.LabelEncoder()
all_tweets['username_id'] = lbl.fit_transform(all_tweets['username'])
all_tweets.head(5)

list_of_original_tweets = [element for element in all_tweets['text'].values if element.startswith('RT')]
print(len(list_of_original_tweets))
list_of_original_tweets[0]
# Out:
# 68
# 'RT:machinelearnbot: RT LifeAtBooz: What skills is your job teaching you? Our employees are tackling #datascience & using it for #socialgood : http:// bit.ly/2lxMKGV pic.twitter.com/P6gctllK2Z'

# %%
all_tweets.describe()
# Out:
#          favorites            id     retweets  count_hashtags  count_mentions  \
# count  1214.000000  1.214000e+03  1214.000000     1214.000000     1214.000000
# mean      2.767710  7.848173e+17     1.931631        4.173806        0.785832
# std       5.863696  1.321034e+17     5.544345        2.631273        1.003011
# min       0.000000  4.466982e+17     0.000000        2.000000        0.000000
# 25%       0.000000  6.696662e+17     0.000000        3.000000        0.000000
# 50%       1.000000  8.144057e+17     0.000000        3.000000        1.000000
# 75%       3.000000  8.933947e+17     2.000000        5.000000        1.000000
# max      95.000000  9.794012e+17    88.000000       27.000000        9.000000
#
#        username_id
# count  1214.000000
# mean    312.545305
# std     177.277099
# min       0.000000
# 25%     153.250000
# 50%     334.000000
# 75%     458.750000
# max     609.000000

# %% [markdown]
# # 2- Analyse each column:

# %%
sns.distplot(all_tweets['favorites']);

# %%
all_tweets['favorites'].describe()
# Out:
# count    1214.000000
# mean        2.767710
# std         5.863696
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         3.000000
# max        95.000000
# Name: favorites, dtype: float64

# %% [markdown]
# **The mean favorite count is : 2.7**

# %%
sns.distplot(all_tweets['retweets']);

# %%
all_tweets['retweets'].describe()
# Out:
# count    1214.000000
# mean        1.931631
# std         5.544345
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         2.000000
# max        88.000000
# Name: retweets, dtype: float64

# %% [markdown]
# **The mean retweets count is : 1.9**

# %%
sns.distplot(all_tweets['count_mentions']);

# %%
all_tweets['count_mentions'].describe()
# Out:
# count    1214.000000
# mean        0.785832
# std         1.003011
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         9.000000
# Name: count_mentions, dtype: float64

# %% [markdown]
# **The mean mentions count is : 0.78**

# %%
sns.distplot(all_tweets['count_hashtags']);

# %%
all_tweets['count_hashtags'].describe()
# Out:
# count    1214.000000
# mean        4.173806
# std         2.631273
# min         2.000000
# 25%         3.000000
# 50%         3.000000
# 75%         5.000000
# max        27.000000
# Name: count_hashtags, dtype: float64

# %% [markdown]
# **The mean hashtag count is : 4.17**

# %%
#sns.distplot(all_tweets['username_id']);
sns.countplot(x="username_id", data=all_tweets.head(100), orient='v');

# %%
all_tweets['username_id'].describe()
# Out:
# count    1214.000000
# mean      312.545305
# std       177.277099
# min         0.000000
# 25%       153.250000
# 50%       334.000000
# 75%       458.750000
# max       609.000000
# Name: username_id, dtype: float64

# %% [markdown]
# **The unique members tweeted are : 609**

# %% [markdown]
# # 3 - See correlations among 2 variables

# %% [markdown]
# **Does the retweet count increases by number of mentions or hashtags ??**
#
# * Obviously, for all tweets with >4 mentions or >10 hashtags, we dont see a high number for re-tweet count in below charts.

# %%
#scatter plot favorites/retweets
var = 'retweets'
data = pd.concat([all_tweets['count_mentions'], all_tweets[var]], axis=1)
data.plot.scatter(x=var, y='count_mentions');

# %%
#scatter plot favorites/retweets
var = 'retweets'
data = pd.concat([all_tweets['count_hashtags'], all_tweets[var]], axis=1)
data.plot.scatter(x=var, y='count_hashtags');

# %% [markdown]
# **Does the favorites count increases by number of mentions or hashtags ??**
#
# * Obviously, for all tweets with >4 mentions or >10 hashtags, we dont see a high number for favorites count in below charts.

# %%
#box plot overallqual/saleprice
var = 'count_mentions'
data = pd.concat([all_tweets['favorites'], all_tweets[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="favorites", data=data)

# %%
#box plot overallqual/saleprice
var = 'count_hashtags'
data = pd.concat([all_tweets['favorites'], all_tweets[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="favorites", data=data)

# %% [markdown]
# **Lets see the correlation among all columns**

# %%
#correlation matrix
corrmat = all_tweets.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
#saleprice correlation matrix
k = 10 #number of variables for heatmap
cols = corrmat.nlargest(k, 'retweets')['retweets'].index
cm = np.corrcoef(all_tweets[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %% [markdown]
# **Observations:**
# 1. 75% correlation between retweet count and favorites count. It makes perfect sense as more people will like if the tweet reach more people.
# 2. This is very interesting to see 23% correlation between tweet_id, hashtag_count. If we see the below correlation between id and count_hashtags, we can see small tendency of using more hastags with increase in id value. This tells that people are using more hastags in recent time than before, makes perfect sense.

# %%
#scatterplot
sns.set()
cols = ['retweets',  'favorites']
sns.pairplot(all_tweets[cols], size = 2.5)
plt.show();

# %%
#scatterplot
sns.set()
cols = ['count_mentions', 'id']
sns.pairplot(all_tweets[cols], size = 2.5)
plt.show();

# %% [markdown]
# # Most Influential people

# %%
def grid_display(list_of_images, list_of_titles=[], no_of_columns=2, figsize=(10,10)):

    fig = plt.figure(figsize=figsize)
    column = 0
    for i in range(len(list_of_images)):
        column += 1
        #  check for end of column and create a new figure
        if column == no_of_columns+1:
            fig = plt.figure(figsize=figsize)
            column = 1
        fig.add_subplot(1, no_of_columns, column)
        img= Image(url = list_of_images[i])
        
        plt.imshow(img)
        plt.axis('off')
        if len(list_of_titles) >= len(list_of_images):
            plt.title(list_of_titles[i])

# %%
def display_influential(df):
    print("profile_name - no_of_tweets - link_to_profile")
    list_of_images = []
    list_of_titles = []
    for index, row in df.iterrows():
        p_url = 'https://twitter.com/'+ row['username'] +'/profile_image?size=normal'
        list_of_images.append(p_url)
        info = "<b>"+ str(row['Size']) + "</b> - " + "<a target='_blank' href='https://twitter.com/" + row['username'] +"'>"+row['username']+'</a>'
        list_of_titles.append(HTML(info))
        
    grid_display(list_of_images, list_of_titles)

# %%
groups = all_tweets.copy(deep=True)
groups = groups[['username_id', 'username']]
groups = groups.groupby(['username_id', 'username']).size().reset_index(name='Size')
groups = groups.sort_values(by=['Size'], ascending=False)
groups = groups[groups['Size'] >= 10]

display_influential(groups)
#https://twitter.com/TwitterEng/profile_image?size=original
# Out:
# profile_name - no_of_tweets - link_to_profile
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-400-e9e52042fa5a> in <module>()
#       5 groups = groups[groups['Size'] >= 10]
#       6
# ----> 7 display_influential(groups)
#       8 #https://twitter.com/TwitterEng/profile_image?size=original
#
# <ipython-input-399-5f457b823f6d> in display_influential(df)
#       9         list_of_titles.append(HTML(info))
#      10
# ---> 11     grid_display(list_of_images, list_of_titles)
#
# <ipython-input-398-84385d7feba6> in grid_display(list_of_images, list_of_titles, no_of_columns, figsize)
#      11         fig.add_subplot(1, no_of_columns, column)
#      12         img= Image(url = list_of_images[i])
# ---> 13         plt.imshow(img)
#      14         plt.axis('off')
#      15         if len(list_of_titles) >= len(list_of_images):
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3099                         filternorm=filternorm, filterrad=filterrad,
#    3100                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3101                         **kwargs)
#    3102     finally:
#    3103         ax._hold = washold
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
#    1718         pre_doc = inner.__doc__
#    1719         if pre_doc is None:
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5129                               resample=resample, **kwargs)
#    5130
# -> 5131         im.set_data(X)
#    5132         im.set_alpha(alpha)
#    5133         if im.get_clip_path() is None:
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/matplotlib/image.py in set_data(self, A)
#     616         if (self._A.dtype != np.uint8 and
#     617                 not np.can_cast(self._A.dtype, float, "same_kind")):
# --> 618             raise TypeError("Image data cannot be converted to float")
#     619
#     620         if not (self._A.ndim == 2
#
# TypeError: Image data cannot be converted to float
